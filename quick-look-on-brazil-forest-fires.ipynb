# %% [markdown]
# <a href="https://www.kaggle.com/code/mohamedabidi97/quick-look-on-s-forest-fires?scriptVersionId=112195173" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# ## ⚡ Introduction
# Forest fire, uncontrolled fire occurring in vegetation more than 1.8 metres (6 feet) in height. These fires often reach the proportions of a major conflagration and are sometimes begun by combustion and heat from surface and ground fires. A big forest fire may crown—that is, spread rapidly through the topmost branches of the trees before involving undergrowth or the forest floor. As a result, violent blowups are common in forest fires, and they may assume the characteristics of a firestorm.

# %% [markdown]
# <img src="https://i.imgur.com/Oe5ZeYx.jpg"></img>

# %% [markdown]
# <div class="alert alert-info"><b>Note:</b> Don't forget to hover your mouse 🖱️ to see values and interact with charts. Enjoy!</div>

# %% [markdown]
# ## 📑 Required libraries

# %%
# Data processing
import numpy as np 
import pandas as pd 

# Data visualization
import plotly.express as px

# %% [markdown]
# ## 🧐 Hello, data!

# %%
df = pd.read_csv('../input/forest-fires-in-brazil/amazon.csv', encoding='latin1')
df.head()
# Out:
#    year state    month  number        date
# 0  1998  Acre  Janeiro     0.0  1998-01-01
# 1  1999  Acre  Janeiro     0.0  1999-01-01
# 2  2000  Acre  Janeiro     0.0  2000-01-01
# 3  2001  Acre  Janeiro     0.0  2001-01-01
# 4  2002  Acre  Janeiro     0.0  2002-01-01

# %% [markdown]
# Year: Year of the wildfire
#
# State: The state where the fires were located
#
# Month: The month in which the fires broke out
#
# Number: The quantity of forest fires
#
# Date: Date of the wildfire

# %%
df.shape
# Out:
# (6454, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6454 entries, 0 to 6453
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    6454 non-null   int64
#  1   state   6454 non-null   object
#  2   month   6454 non-null   object
#  3   number  6454 non-null   float64
#  4   date    6454 non-null   object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 252.2+ KB

# %%
df.month.unique()
# Out:
# array(['Janeiro', 'Fevereiro', 'Março', 'Abril', 'Maio', 'Junho', 'Julho',
#        'Agosto', 'Setembro', 'Outubro', 'Novembro', 'Dezembro'],
#       dtype=object)

# %% [markdown]
# <div class="alert alert-warning"><b>Warning:</b> The month's column in this dataset is not in English, all of them are in Portugues</div>

# %%
df.state.unique()
# Out:
# array(['Acre', 'Alagoas', 'Amapa', 'Amazonas', 'Bahia', 'Ceara',
#        'Distrito Federal', 'Espirito Santo', 'Goias', 'Maranhao',
#        'Mato Grosso', 'Minas Gerais', 'Pará', 'Paraiba', 'Pernambuco',
#        'Piau', 'Rio', 'Rondonia', 'Roraima', 'Santa Catarina',
#        'Sao Paulo', 'Sergipe', 'Tocantins'], dtype=object)

# %%
df.year.unique()
# Out:
# array([1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008,
#        2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017])

# %% [markdown]
# <div class="alert alert-info"><b>Information:</b> The records are from 1998 to 2017</div>

# %% [markdown]
# ## ⚙️ Changes needed

# %%
df['month'] = df['month'].replace('Janeiro','Jan')
df['month'] = df['month'].replace('Fevereiro','Feb')
df['month'] = df['month'].replace('Março','Mar')
df['month'] = df['month'].replace('Abril','Apr')
df['month'] = df['month'].replace('Maio','May')
df['month'] = df['month'].replace('Junho','Jun')
df['month'] = df['month'].replace('Julho','Jul')
df['month'] = df['month'].replace('Agosto','Aug')
df['month'] = df['month'].replace('Setembro','Sep')
df['month'] = df['month'].replace('Outubro','Oct')
df['month'] = df['month'].replace('Novembro','Nov')
df['month'] = df['month'].replace('Dezembro','Dec')

# %%
df.month.unique()
# Out:
# array(['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec'], dtype=object)

# %%
df['date'] = pd.to_datetime(df.date)

# %%
# Create 'year' column
df['year'] = pd.DatetimeIndex(df['date']).year

# %% [markdown]
# ## 📊 It's the charts time

# %% [markdown]
# <mark><font color=#FF0000><b>The burning season:</b></font></mark>
# From June to December, the southern Amazon Basin dries out, and fires can become a concern. Most are caused by human activity, especially clearing lands for farming.
#
# <mark><font color=#FF0000><b>Summer-time</b></font></mark> in Brazil is from December through March, and winter is June through September but the further north you go, the higher the temperature and the humidity. In fact, the Northeast is too hot to have a winter.

# %% [markdown]
# <center><img src="https://images.mapsofworld.com/brazil/brazil-cities-map.jpg" /></center>

# %%
year_fires = df.groupby(['year'])['number'].sum().reset_index().sort_values('year', ascending=True)
fig = px.line(year_fires, x = 'year', y = "number", color_discrete_sequence = ['red'])
fig.update_yaxes(showgrid=True)
fig.update_xaxes(showgrid=True)
fig.update_traces(line_width=5)
fig.update_layout(plot_bgcolor= 'white')

# Add image https://i.imgur.com/QqYkbw3.png
fig.add_layout_image(
    dict(
        source="https://i.imgur.com/QqYkbw3.png",
        xref="paper", yref="paper",
        y=1,
        opacity= 0.1,
        sizex=0.7, sizey=1,
        xanchor="left", yanchor="top"
    )
)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="fe5ca1c3-6994-4659-b100-a16af5254bcb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe5ca1c3-6994-4659-b100-a16af5254bcb")) {                    Plotly.newPlot(                        "fe5ca1c3-6994-4659-b100-a16af5254bcb",                        [{"hovertemplate":"year=%{x}<br>number=%{y}<extra></extra>","legendgroup":"","line":{"color":"red","dash":"solid","width":5},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[20013.971,26882.821,27351.251,29071.612,37390.6,42760.674,38453.163,35004.965,33832.161,33037.413,29378.964,39117.178,37037.449,34633.545,40084.86,35146.118,39621.183,41208.292,42212.229,36685.624],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0. ...

# %% [markdown]
# <div class="alert alert-success">
#   <div class="alert-content">
#     <h2 class="alert-title">
#       💡 Interpretation
#     </h2>
#     <div class="alert-body">
#       <p>It is quite clear that the number of wildfires has increased during those years. </p>
#     </div>
#   </div>
# </div>
# <div class="alert alert-info">
#   <div class="alert-content">
#     <h2 class="alert-title">
#       💡 Extra Information
#     </h2>
#     <div class="alert-body">
#       <p>In 2010, Brazil had 492Mha of natural forest, extending over 59% of its land area. In 2021, it lost 2.90Mha of natural forest, equivalent to 1.70Gt of CO₂ emissions.</p>
#     </div>
#   </div>
# </div>

# %% [markdown]
# #### Let's see the number of wildfires each Month:

# %%
month_number = df.groupby('month')['number'].sum().reset_index().sort_values('number', ascending=False)
fig = px.bar(month_number, x='month', y='number', color='number', color_continuous_scale='RdYlGn_r')
fig.update_yaxes(showgrid=False)
fig.update_xaxes(showgrid=False)
fig.update_layout(plot_bgcolor= 'white')
fig.show()
# Out:
# <div>                            <div id="327f98b3-d3c3-4489-965e-781d875fefee" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("327f98b3-d3c3-4489-965e-781d875fefee")) {                    Plotly.newPlot(                        "327f98b3-d3c3-4489-965e-781d875fefee",                        [{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>number=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[92326.113,88681.579,88050.435,85508.054,58578.305,57535.48,56010.675,47747.844,34731.363,30848.05,30717.405,28188.77],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Jul","Oct","Aug","Nov","Sep","Dec","Jun","Jan","May","Feb","Mar","Apr"],"xaxis":"x","y":[92326.113,88681.579,88050.435,85508.054,58578.305,57535.48,56010.675,47747.844,34731.363,30848.05,30717.405,28188.77],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":" ...

# %% [markdown]
# <div class="alert alert-success">
#   <div class="alert-content">
#     <h2 class="alert-title">
#       💡 Interpretation:
#     </h2>
#     <div class="alert-body">
#       <p>It is evident that the winter months of July, October, and August have the biggest number.
# Maybe because the majority of the northern states could be included, where it is almost always hot. Additionally, as I already stated, human activity is the main cause of wildfires.</p>
#     </div>
#   </div>
# </div>

# %% [markdown]
# #### It is preferable to gain knowledge of Brazil's yearly average temperature.

# %% [markdown]
# <center><img src="https://www.researchgate.net/profile/Clayton-Alcarde-Alvares/publication/263088914/figure/fig9/AS:668571617210369@1536411303159/Digital-elevation-model-of-Brazil-Figure-4-Annual-mean-air-temperature-map-for-Brazil_Q640.jpg" /></center>

# %%
state_number= df.groupby('state')['number'].sum().sort_values(ascending = False).head(10).reset_index()
state_number.style.background_gradient(subset='number', cmap='YlOrRd')
# Out:
# <style type="text/css">
# #T_90df3_row0_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
# }
# #T_90df3_row1_col1 {
#   background-color: #febf5a;
#   color: #000000;
# }
# #T_90df3_row2_col1 {
#   background-color: #fec662;
#   color: #000000;
# }
# #T_90df3_row3_col1 {
#   background-color: #fede80;
#   color: #000000;
# }
# #T_90df3_row4_col1 {
#   background-color: #fede82;
#   color: #000000;
# }
# #T_90df3_row5_col1, #T_90df3_row6_col1 {
#   background-color: #fff0a7;
#   color: #000000;
# }
# #T_90df3_row7_col1 {
#   background-color: #fff0a8;
#   color: #000000;
# }
# #T_90df3_row8_col1 {
#   background-color: #fff9bd;
#   color: #000000;
# }
# #T_90df3_row9_col1 {
#   background-color: #ffffcc;
#   color: #000000;
# }
# </style>
# <table id="T_90df3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >state</th>
#       <th class="col_heading level0 col1" >number</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_90df3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_90df3_row0_col0" class="data row0 col0" >Mato Grosso</td>
#       <td id="T_90df3_row0_col1" class="data row0 col1" >96246.028000</td>
#     </tr>
#     <tr>
#       <th id="T_90df3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_90df3_row1_col0" class="data row1 col0" >Paraiba</td>
#       <td id="T_90df3_row1_col1" class="data row1 col1" >52435.918000</td>
#     </tr>
#     <tr>
#       <th id="T_90df3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_90df3_row2_col0" class="data row2 col0" >Sao Paulo</td>
#       <td id="T_90df3_row2_col1" class="data row2 col1" >51121.198000</td>
#     </tr>
#     <tr>
#       <th id="T_90df3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_90df3_row3_col0" class="data row3 col0" >Rio</td>
#       <td id="T_90df3_row3_col1" class="data row3 col1" >45160.865000</td>
#     </tr>
#     <tr>
#       <th id="T_90df3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_90df3_row4_col0" class="data row4 col0" >Bahia</td>
#       <td id="T_90df3_row4_col1" class="data row4 col1" >44746.226000</td>
#     </tr>
#     <tr>
#       <th id="T_90df3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_90df3_row5_col0" class="data row5 col0" >Piau</td>
#       <td id="T_90df3_row5_col1" class="data row5 col1" >37803.747000</td>
#     </tr>
#     <tr>
#       <th id="T_90df3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_90df3_row6_col0" class="data row6 col0" >Goias</td>
#       <td id="T_90df3_row6_col1" class="data row6 col1" >37695.520000</td>
#     </tr>
#     <tr>
#       <th id="T_90df3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_90df3_row7_col0" class="data row7 col0" >Minas Gerais</td>
#       <td id="T_90df3_row7_col1" class="data row7 col1" >37475.258000</td>
#     </tr>
#     <tr>
#       <th id="T_90df3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_90df3_row8_col0" class="data row8 col0" >Tocantins</td>
#       <td id="T_90df3_row8_col1" class="data row8 col1" >33707.885000</td>
#     </tr>
#     <tr>
#       <th id="T_90df3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_90df3_row9_col0" class="data row9 col0" >Amazonas</td>
#       <td id="T_90df3_row9_col1" class="data row9 col1" >30650.129000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It is kind of strange to see Mato Grosso, Paraiba, and Sea Paulo as the states with the most wildfires rather than Amazonas.🤔 <br>
# <mark><font color=#FF0000><b>Why? </b></font></mark><br>
# Perhaps because the vast Amazon zone, where the majority of fires occur, is nearby in the South of the Amazon.

# %% [markdown]
# #### Mato Grosso is a component of the Amazon Area, as you can see in the picture.

# %% [markdown]
# <center><img style="width: 550px"src="https://www.amazonconservation.org/wp-content/uploads/2019/11/maaproject.org-maap-113-satellites-reveal-what-fueled-brazilian-amazon-fires-BrazilianAmazon-v3-Fires2019-PrimarySecundaryForestLoss-Eng-200dpi-1500x1164-1.jpg" /></center>

# %%
fig = px.bar(state_number, x='state', y='number', color='number', color_continuous_scale='RdYlGn_r')
fig.update_yaxes(showgrid=False)
fig.update_xaxes(showgrid=False)
fig.update_layout(plot_bgcolor= 'white')
fig.show()
# Out:
# <div>                            <div id="697769d5-090b-432e-8329-fd9e19c37078" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("697769d5-090b-432e-8329-fd9e19c37078")) {                    Plotly.newPlot(                        "697769d5-090b-432e-8329-fd9e19c37078",                        [{"alignmentgroup":"True","hovertemplate":"state=%{x}<br>number=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[96246.028,52435.918,51121.198,45160.865,44746.226,37803.747,37695.52,37475.258,33707.885,30650.129],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Mato Grosso","Paraiba","Sao Paulo","Rio","Bahia","Piau","Goias","Minas Gerais","Tocantins","Amazonas"],"xaxis":"x","y":[96246.028,52435.918,51121.198,45160.865,44746.226,37803.747,37695.52,37475.258,33707.885,30650.129],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f ...

# %% [markdown]
# #### Check out the wildfires that occurred in the TOP 3 states throughout those years.

# %%
rio_data = df.query("state in ('Sao Paulo','Mato Grosso', 'Paraiba')")
rio_year_number = rio_data.groupby(['year', 'state'])['number'].sum().reset_index().sort_values('year', ascending=True)

# %%
fig = px.line(rio_year_number, x = 'year', y = "number", color="state", color_discrete_sequence = ['red', 'darkorange', 'darkgreen'])

fig.update_yaxes(showgrid=False)
fig.update_xaxes(showgrid=False)
fig.update_traces(line_width=5)
fig.update_layout(plot_bgcolor= 'white')

# Add image https://i.imgur.com/QqYkbw3.png
fig.add_layout_image(
    dict(
        source="https://i.imgur.com/QqYkbw3.png",
        xref="paper", yref="paper",
        y=1,
        opacity= 0.1,
        sizex=0.7, sizey=1,
        xanchor="left", yanchor="top"
    )
)
fig.show()
# Out:
# <div>                            <div id="6cf0ed2a-7ec4-439e-ab62-4f71c23d8ad9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6cf0ed2a-7ec4-439e-ab62-4f71c23d8ad9")) {                    Plotly.newPlot(                        "6cf0ed2a-7ec4-439e-ab62-4f71c23d8ad9",                        [{"hovertemplate":"state=Mato Grosso<br>year=%{x}<br>number=%{y}<extra></extra>","legendgroup":"Mato Grosso","line":{"color":"red","dash":"solid","width":5},"marker":{"symbol":"circle"},"mode":"lines","name":"Mato Grosso","orientation":"v","showlegend":true,"x":[1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[2401.389,2979.399,3897.266,3088.075,3665.503,6939.854,4811.176,5386.715,4286.385,3515.7039999999997,3399.9030000000002,8188.717,6252.445,5388.206,5341.25,5238.111,5890.597,6261.0869999999995,3652.919,5661.327],"yaxis":"y","type":"scatter"},{"hovertemplate":"state=Paraiba<br>year=%{x}<br>number=%{y}<extra></extra>","legendgroup":"Paraiba","line":{"color":"darkorange","dash":"solid","width":5},"marker":{"symbol":"circle"},"mode":"lines","name":"Paraiba","orientation":"v","showlegend":true,"x":[1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[816.0,3437.0,2804.0,2073.0,2248.6639999999998,2796.57,2760.5969999999998,3427.0,3308.0,2665.0,1689.0,2963.0,2711.0,3280.0,2285.0,2225.0,2742.0,2773.0,2379.381,3052.706],"yaxis":"y","type":"scatter"},{"hovertemplate":"state=Sao Paulo<br>year=%{x}<br>number=%{y}<extra></extra>","legendgroup":"Sao Paulo","line":{"color":"darkgreen","dash":"solid","width":5},"marker":{"symbol":"circle"},"mode":"lines","name":"Sao Paulo","orientation":"v","showlegend":true,"x":[1998,1999,2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017],"xaxis":"x","y":[3196.0,4249.211,4128.0,2926.0,3539.0,3306.0,2864.0,2123.0,2209.0,1877.0,1193.0,1165.0,1711.4859999999999,1400.175,2159.0,2055.0,3260.458,1984.0,3235.0,2540.868],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks": ...

# %% [markdown]
# From <b>2001 to 2021</b>, Mato Grosso lost <b>2.72Mha</b> of tree cover from fires and 9.91Mha from all other drivers of loss. The year with the most tree cover loss due to fires during this period was 2020 with 556kha lost to fires —<b> 64%</b> of all tree cover loss for that year.
#
#
# <a href="https://www.globalforestwatch.org/dashboards/country/BRA/?category=summary&dashboardPrompts=...%3D&fireAlertStats=eyJzdGFydEluZGV4IjoyMCwiZW5kSW5kZXgiOjUxLCJzdGFydERhdGVBYnNvbHV0ZSI6IjIwMjItMDQtMTEiLCJlbmREYXRlQWJzb2x1dGUiOiIyMDIyLTExLTE0In0%3D&gladAlerts=eyJ3ZWVrcyI6NTJ9&location=WyJjb3VudHJ5IiwiQlJBIiwiMTIiXQ%3D%3D&map=...%3D&showMap=true">🔗 Source </a>

# %% [markdown]
# #### Number of forestfires of Mato Grosso per month 🔥

# %%
mato_grosso_df = df.query("state == 'Mato Grosso'")
month_fires = mato_grosso_df.groupby('month')['number'].sum().sort_values(ascending = False).reset_index()

# %%
fig = px.bar(month_fires, x='month', y='number', color='number', color_continuous_scale='RdYlGn_r', text_auto='.2s')

fig.update_xaxes(categoryorder='array', categoryarray= ['Jan', 'Febr', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
fig.update_yaxes(showgrid=False)
fig.update_xaxes(showgrid=False)
fig.update_layout(plot_bgcolor= 'white')

fig.add_layout_image(
    dict(
        source="https://i.imgur.com/QqYkbw3.png",
        xref="paper", yref="paper",
        y=1,
        opacity= 0.1,
        sizex=0.7, sizey=1,
        xanchor="left", yanchor="top"
    )
)
fig.show()
# Out:
# <div>                            <div id="6a760279-f2dc-4ddf-aa49-529ccd7dc75c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a760279-f2dc-4ddf-aa49-529ccd7dc75c")) {                    Plotly.newPlot(                        "6a760279-f2dc-4ddf-aa49-529ccd7dc75c",                        [{"alignmentgroup":"True","hovertemplate":"month=%{x}<br>number=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[10480.0,10167.585000000001,10158.363,9952.77,9923.363,9613.085,7594.773,7465.338,7456.05,7090.606,4728.32,1615.775],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y:.2s}","x":["Jan","Nov","May","Apr","Oct","Mar","Dec","Jul","Feb","Jun","Aug","Sep"],"xaxis":"x","y":[10480.0,10167.585000000001,10158.363,9952.77,9923.363,9613.085,7594.773,7465.338,7456.05,7090.606,4728.32,1615.775],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f" ...

# %% [markdown]
# ## End
# A lot of wildland fires  are caused by humans. Human-caused fires result from campfires left unattended, the burning of debris, equipment use and malfunctions, negligently discarded cigarettes, and intentional acts of arson.
#
# And this is really tragic 😞, not just for the environment but also for the firefighters who take so many dangers to address those careless human mistakes.

# %% [markdown]
# <img src="https://i.imgur.com/PdwU04l.jpg"></img>

# %% [markdown]
# <div class="alert alert-info">
#   <div class="alert-content">
#     <h2 class="alert-title">
#       Thank you 🙏
#     </h2>
#     <div class="alert-body">
#       <p>if you appreciate the work.Vote up ☝️, it would be greatly appreciated. </p>
#     </div>
#   </div>
# </div>
